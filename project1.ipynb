# %%
""" 교통사고 """

#1
import pandas as pd
import numpy as np
import networkx as nx

accident = pd.read_csv('acci.csv', engine='python')
accident.head()
# Out:
#   Violation of the law 주야  Number of occurrences  death toll  injured person  \
# 0         overspeeding  주                    159          34             334
# 1         overspeeding  야                    218          73             348
# 2       traffic method  주                   8817          82           14031
# 3       traffic method  야                   5904          29            9728
# 4                  etc  주                   9388         141           14070
#
#    a heavy wound  a minor injury  Report of injury
# 0            140             178                16
# 1            200             139                 9
# 2           3915            9530               586
# 3           2401            6884               443
# 4           4271            9217               582

# %%
#2
group_names = ['적다','보통','많다']
accident['amount of damage'],mybin = pd.cut(accident['injured person'],3,labels=group_names,retbins=True)
accident
# Out:
#                  Violation of the law 주야  Number of occurrences  death toll  \
# 0                        overspeeding  주                    159          34
# 1                        overspeeding  야                    218          73
# 2                      traffic method  주                   8817          82
# 3                      traffic method  야                   5904          29
# 4                                 etc  주                   9388         141
# 5                                 etc  야                   6073          56
# 6          Pedestrian Protection Duty  주                   3772          80
# 7          Pedestrian Protection Duty  야                   3334          94
# 8                    Signal violation  주                  12552         210
# 9                    Signal violation  야                  12755         179
# 10        Safety distance not secured  주                  12408          57
# ...

# %%
#3
import numpy as np
pd.get_dummies(accident)
pd.get_dummies(accident,columns = ['주야'])
pd.get_dummies(accident['주야'], drop_first=False)
# Out:
#     야  주
# 0   0  1
# 1   1  0
# 2   0  1
# 3   1  0
# 4   0  1
# 5   1  0
# 6   0  1
# 7   1  0
# 8   0  1
# 9   1  0
# 10  0  1
# 11  1  0
# 12  0  1
# 13  1  0
# 14  0  1
# 15  1  0

# %%
#4
import pandas as pd
data = pd.DataFrame(accident, columns=['Violation of the law','주야','Number of occurrences','death toll',
                                       'injured person','a heavy wound','a minor injury','Report of injury'])
data
# Out:
#                  Violation of the law 주야  Number of occurrences  death toll  \
# 0                        overspeeding  주                    159          34
# 1                        overspeeding  야                    218          73
# 2                      traffic method  주                   8817          82
# 3                      traffic method  야                   5904          29
# 4                                 etc  주                   9388         141
# 5                                 etc  야                   6073          56
# 6          Pedestrian Protection Duty  주                   3772          80
# 7          Pedestrian Protection Duty  야                   3334          94
# 8                    Signal violation  주                  12552         210
# 9                    Signal violation  야                  12755         179
# 10        Safety distance not secured  주                  12408          57
# ...

# %%
#4
accident.isnull().sum()
# Out:
# Violation of the law     0
# 주야                       0
# Number of occurrences    0
# death toll               0
# injured person           0
# a heavy wound            0
# a minor injury           0
# Report of injury         0
# amount of damage         0
# dtype: int64

# %%
#5
accident['a heavy wound'] = (accident['a heavy wound']-accident['a heavy wound'].min())/(accident['a heavy wound'].max()- accident['a heavy wound'].min())
accident
# Out:
#                  Violation of the law 주야  Number of occurrences  death toll  \
# 0                        overspeeding  주                    159          34
# 1                        overspeeding  야                    218          73
# 2                      traffic method  주                   8817          82
# 3                      traffic method  야                   5904          29
# 4                                 etc  주                   9388         141
# 5                                 etc  야                   6073          56
# 6          Pedestrian Protection Duty  주                   3772          80
# 7          Pedestrian Protection Duty  야                   3334          94
# 8                    Signal violation  주                  12552         210
# 9                    Signal violation  야                  12755         179
# 10        Safety distance not secured  주                  12408          57
# ...

# %%
#6
#결정트리
accident_feature = accident[['Violation of the law','주야','Number of occurrences','death toll','injured person',
                             'a heavy wound','a minor injury','Report of injury']]
feature = np.array(accident_feature)
accident_names = accident['Report of injury']
names = np.array(accident_names)
X = feature
y = names

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.5)

from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf.fit(X_train, y_train)
predictions = clf.predict(X_test)
print('예측:\n', predictions)
print('정답(y_test):\n', y_test)

from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, predictions))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-88b2742d2c8a> in <module>
#      14 from sklearn import tree
#      15 clf = tree.DecisionTreeClassifier()
# ---> 16 clf.fit(X_train, y_train)
#      17 predictions = clf.predict(X_test)
#      18 print('예측:\n', predictions)
#
# C:\anaconda\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     875             sample_weight=sample_weight,
#     876             check_input=check_input,
# --> 877             X_idx_sorted=X_idx_sorted)
#     878         return self
#     879
#
# C:\anaconda\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     147
#     148         if check_input:
# --> 149             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
# ...

# %%
# K 최근접 이웃
accident_feature = accident[['Violation of the law','주야','Number of occurrences','death toll','injured person',
                             'a heavy wound','a minor injury','Report of injury']]
feature = np.array(accident_feature)
accident_names = accident['Report of injury']
names = np.array(accident_names)
X = feature
y = names

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.5)

from sklearn.neighbors import KNeighborsClassifier
clf = KNeighborsClassifier()
clf.fit(X_train, y_train)
predictions = clf.predict(X_test)
print('예측:\n', predictions)
print('정답(y_test):\n', y_test)

from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, predictions))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-45c6b09c05fe> in <module>
#      13 from sklearn.neighbors import KNeighborsClassifier
#      14 clf = KNeighborsClassifier()
# ---> 15 clf.fit(X_train, y_train)
#      16 predictions = clf.predict(X_test)
#      17 print('예측:\n', predictions)
#
# C:\anaconda\lib\site-packages\sklearn\neighbors\_base.py in fit(self, X, y)
#    1128         """
#    1129         if not isinstance(X, (KDTree, BallTree)):
# -> 1130             X, y = check_X_y(X, y, "csr", multi_output=True)
#    1131
#    1132         if y.ndim == 1 or y.ndim == 2 and y.shape[1] == 1:
#
# C:\anaconda\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...
